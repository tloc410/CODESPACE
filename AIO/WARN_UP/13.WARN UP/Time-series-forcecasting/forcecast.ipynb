# %%
# %pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
co2_levels = pd.read_csv('co2_levels.csv')
co2_levels = co2_levels.ffill()
co2_levels.head()
# Out:
#     datestamp    co2
# 0  1958-03-29  316.1
# 1  1958-04-05  317.3
# 2  1958-04-12  317.6
# 3  1958-04-19  317.5
# 4  1958-04-26  316.4

# %%
co2_levels['datestamp'] = pd.to_datetime(co2_levels['datestamp'])

# set datetamp column as index
co2_levels = co2_levels.set_index('datestamp')

# %%
co2_levels
# Out:
#               co2
# datestamp
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4
# ...           ...
# 2001-12-01  370.3
# 2001-12-08  370.8
# 2001-12-15  371.2
# 2001-12-22  371.3
# 2001-12-29  371.5
#
# [2284 rows x 1 columns]

# %% [markdown]
# ### Decomposition

# %%
decomposition = sm.tsa.seasonal_decompose(co2_levels['co2'])
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ### Time-based Features

# %%
co2_levels['year'] = co2_levels.index.year
co2_levels['month'] = co2_levels.index.month
co2_levels['day'] = co2_levels.index.day 

co2_levels.head()
# Out:
#               co2  year  month  day
# datestamp
# 1958-03-29  316.1  1958      3   29
# 1958-04-05  317.3  1958      4    5
# 1958-04-12  317.6  1958      4   12
# 1958-04-19  317.5  1958      4   19
# 1958-04-26  316.4  1958      4   26
